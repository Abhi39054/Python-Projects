# %%
# Twitter Sentiment Analysis

# %%
# Python Imports

import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from nltk.stem import WordNetLemmatizer

from wordcloud import WordCloud, STOPWORDS

# %matplotlib inline

# %%
# Load the dataset

df = pd.read_csv("Sentiment.csv")

# %%
df.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# 0                     1.0000            NaN  ...              NaN
# 1                     1.0000            NaN  ...              NaN
# 2                     0.6629            NaN  ...              NaN
# 3                     0.7039            NaN  ...              NaN
# 4                     1.0000            NaN  ...              NaN
#
#   retweet_count  sentiment_gold subject_matter_gold  \
# 0             5             NaN                 NaN
# 1            26             NaN                 NaN
# 2            27             NaN                 NaN
# 3           138             NaN                 NaN
# 4           156             NaN                 NaN
#
#                                                 text tweet_coord  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2  RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3  RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
#
#                tweet_created            tweet_id  tweet_location  \
# 0  2015-08-07 09:54:46 -0700  629697200650592256             NaN
# 1  2015-08-07 09:54:46 -0700  629697199560069120             NaN
# 2  2015-08-07 09:54:46 -0700  629697199312482304             NaN
# 3  2015-08-07 09:54:45 -0700  629697197118861312           Texas
# 4  2015-08-07 09:54:45 -0700  629697196967903232             NaN
#
#                 user_timezone
# 0                       Quito
# 1                         NaN
# 2                         NaN
# 3  Central Time (US & Canada)
# 4                     Arizona
#
# [5 rows x 21 columns]

# %%
# Lets only take text and sentiment

df = df[["text", "sentiment"]]

# %%
df.head()
# Out:
#                                                 text sentiment
# 0  RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2  RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3  RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive

# %%
## Data Cleaning

# %%
df.text[0]
# Out:
# 'RT @NancyLeeGrahn: How did everyone feel about the Climate Change question last night? Exactly. #GOPDebate'

# %%
lemmatizer = WordNetLemmatizer()

def clean_text(text):

    # lower
    text = text.lower()

    # remove \n
    text = " ".join(text.split("\n"))

    # remove url
    text = re.sub(r'https?:\S*', '', text)

    # remove twitter mentions accounts (@users)
    text = re.sub(r"@\S*", '', text)

    # remove non alpha words to preserve the !?
    text = re.sub(r"[^A-Za-z!?]", ' ', text)

    # remove extra spaces
    text = re.sub(r"\s+", " ", text)

    # remove stopwords
    custom_preseve_stopwords = ["no", "not", "never"]
    tokens = [ x for x in text.split(" ") if (x not in stopwords.words("english") or x in custom_preseve_stopwords) and len(x)>=2]

    # apply lemmatization
    tokens = [lemmatizer.lemmatize(x) for x in tokens]

    return " ".join(tokens)

# %%
clean_text(df.text[0]+"  no not never")
# Out:
# 'rt everyone feel climate change question last night? exactly gopdebate no not never'

# %%
df.shape
# Out:
# (13871, 3)

# %%
df["clean_text"] = df["text"].apply(clean_text)

# %%
df
# Out:
#                                                     text sentiment  \
# 0      RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2      RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3      RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
# ...                                                  ...       ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...  Negative
# 13867  RT @georgehenryw: Who thought Huckabee exceede...  Positive
# 13868  RT @Lrihendry: #TedCruz As President, I will a...  Positive
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...  Negative
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...  Positive
#
#                                               clean_text
# 0      rt everyone feel climate change question last ...
# 1      rt catch full gopdebate last night scott best ...
# 2      rt no mention tamir rice gopdebate held clevel...
# 3      rt carly fiorina trending hour debate men comp...
# 4      rt gopdebate delivered highest rating history ...
# ...                                                  ...
# 13866  rt love see men never faced pregnancy talk bod...
# 13867  rt thought huckabee exceeded expectation gopde...
# 13868  rt tedcruz president always tell truth said wo...
# 13869  rt gopdebate donald trump say time political c...
# 13870  rt tedcruz headed presidential debate go ted!!...
#
# [13871 rows x 3 columns]

# %%
# Split the dataset into training and test set
X = df["clean_text"]
y = df["sentiment"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=41)

# %%
# Apply label encoder for sentiment.
encoder = LabelEncoder()


y_train_encoded = encoder.fit_transform(y_train)
y_test_encoded = encoder.transform(y_test)

# %%
# Apply tfidf vecotrier

vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_features=5000, stop_words='english')

X_train_ecoded =vectorizer.fit_transform(X_train)
X_test_encoded = vectorizer.transform(X_test)

# %%
vectorizer.get_feature_names_out()[:10]
# Out:
# array(['aaaand', 'abandon', 'abc', 'able', 'abortion',
#        'abortion gopdebate', 'abraham', 'abraham lincoln', 'absolutely',
#        'absolutely fearful'], dtype=object)

# %%
print("Vocabulary length:", len(vectorizer.get_feature_names_out()))
# Out:
# Vocabulary length: 5000

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB, BernoulliNB

from sklearn.metrics import accuracy_score, classification_report

# %%
model_params = {
    "LogisticRegression":LogisticRegression(),
    "SVC":SVC(),
    "MultiNomiial MNB": MultinomialNB(),
    "BernoulliNB":BernoulliNB()
}

# %%
for model_name, model in model_params.items():
    print("="*30)
    print("Name : ", model_name)

    model.fit(X_train_ecoded, y_train_encoded)
    y_pred = model.predict(X_test_encoded)

    ascore = accuracy_score(y_test_encoded, y_pred)
    print("Accuracy Score = ", ascore)
    print("\nClassification Report:\n")
    print(classification_report(y_test_encoded, y_pred, target_names=encoder.classes_))
# Out:
# ==============================
# Name :  LogisticRegression
# Accuracy Score =  0.6954954954954955
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     Negative       0.74      0.90      0.81      1770
#      Neutral       0.50      0.27      0.35       598
#     Positive       0.61      0.44      0.51       407
#
#     accuracy                           0.70      2775
#    macro avg       0.62      0.54      0.56      2775
# weighted avg       0.67      0.70      0.67      2775
#
# ==============================
# Name :  SVC
# Accuracy Score =  0.6969369369369369
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     Negative       0.72      0.92      0.81      1770
#      Neutral       0.55      0.24      0.33       598
#     Positive       0.66      0.40      0.50       407
#
#     accuracy                           0.70      2775
#    macro avg       0.64      0.52      0.55      2775
# weighted avg       0.67      0.70      0.66      2775
#
# ==============================
# Name :  MultiNomiial MNB
# Accuracy Score =  0.6864864864864865
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     Negative       0.72      0.90      0.80      1770
#      Neutral       0.48      0.27      0.35       598
#     Positive       0.64      0.38      0.48       407
#
#     accuracy                           0.69      2775
#    macro avg       0.62      0.52      0.54      2775
# weighted avg       0.66      0.69      0.66      2775
#
# ==============================
# Name :  BernoulliNB
# Accuracy Score =  0.6075675675675676
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     Negative       0.82      0.63      0.71      1770
#      Neutral       0.36      0.62      0.45       598
#     Positive       0.53      0.48      0.50       407
#
#     accuracy                           0.61      2775
#    macro avg       0.57      0.58      0.56      2775
# weighted avg       0.68      0.61      0.63      2775
